# %%
import pandas as pd
from src.utils import *
import IPython.display as ipd

# %%
config_path = 'config/residualnet_train_config.yaml'
config = read_yaml(config_path)

# %%
df_eval = pd.read_csv(config['df_eval_path'])
file_eval = list(df_eval['path'])

# get the single file path
index = 0
file = file_eval[index]
print(f'Evaluating file {file}')
# Out:
# Evaluating file /nas/public/dataset/asvspoof2021/ASVspoof2021_DF_eval/flac/DF_E_2000011.flac

# %%
ipd.Audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>
